# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')
import json

# %%
from rlagent import QLAgent
from tokyodrift import TokyoDriftEnv, get_default_coursemap, get_driftmap

# %%
q = QLAgent(max_episode_len=200, gamma=1, alpha=0.1, epsilon=0.999, epsilon_shrink=0.99)

# %%
env = TokyoDriftEnv(get_driftmap())

# %%
q.fit(env, 10000)

# %%
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
env.reset()
env.render()
done = False

# %%
# while not done:
action = q._greedy_move(env.int_state)
print(action)
s, r, done, _ = env.step(action)
print(env.velocity)
print(s, r, done)
if env._is_wall(env.state):
    print('crash')
env.render().style.applymap(lambda x: 'background-color: red' if x == 4 else '')
# Out:
# 0
# [0 2]
# 3977 0 True
# <style type="text/css">
# #T_d1b61_row4_col31 {
#   background-color: red;
# }
# </style>
# <table id="T_d1b61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1b61_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d1b61_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d1b61_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d1b61_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_d1b61_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_d1b61_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_d1b61_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_d1b61_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_d1b61_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_d1b61_level0_col9" class="col_heading level0 col9" >9</th>
# ...
